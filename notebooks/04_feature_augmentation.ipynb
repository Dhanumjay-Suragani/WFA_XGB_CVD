# %%
import os
import sys
from pathlib import Path

print("Current working directory:")
print(os.getcwd())

cwd = Path.cwd()
print("\nParents of CWD:")
for i, p in enumerate(cwd.parents):
    print(f"{i}: {p}")

print("\nInitial sys.path (first 5):")
for p in sys.path[:5]:
    print(p)
# Resolve project root: wfa_xgb_cvd_prediction
# Out:
# Current working directory:
# c:\Users\dhanu\OneDrive\Desktop\CD_Main\wfa_xgb_cvd_prediction\notebooks
#
# Parents of CWD:
# 0: c:\Users\dhanu\OneDrive\Desktop\CD_Main\wfa_xgb_cvd_prediction
# 1: c:\Users\dhanu\OneDrive\Desktop\CD_Main
# 2: c:\Users\dhanu\OneDrive\Desktop
# 3: c:\Users\dhanu\OneDrive
# 4: c:\Users\dhanu
# 5: c:\Users
# 6: c:\
#
# Initial sys.path (first 5):
# C:\Users\dhanu\AppData\Local\Programs\Python\Python311\python311.zip
# C:\Users\dhanu\AppData\Local\Programs\Python\Python311\DLLs
# C:\Users\dhanu\AppData\Local\Programs\Python\Python311\Lib
# C:\Users\dhanu\AppData\Local\Programs\Python\Python311
# c:\Users\dhanu\OneDrive\Desktop\CD_Main\wfa_xgb_cvd_prediction\wfa_xgb_env

# %%
# ---- Project path fix (DO NOT SKIP) ----
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parents[0]  # ✅ VERIFIED CORRECT

if not (PROJECT_ROOT / "src").exists():
    raise RuntimeError(f"'src' not found at {PROJECT_ROOT}")

sys.path.insert(0, str(PROJECT_ROOT))

print("✅ Project root set to:", PROJECT_ROOT)
# Out:
# ✅ Project root set to: c:\Users\dhanu\OneDrive\Desktop\CD_Main\wfa_xgb_cvd_prediction

# %%
from src.config.paths import (
    HEART_VERIFIED_CSV,
    BASELINE_RESULTS_CSV,
    WFA_FEATURE_WEIGHTS_CSV,
    FEATURE_AUGMENTED_WEIGHTS_CSV,
    BASELINE_MODEL_PKL,
    WFA_XGB_MODEL_JSON
)

# %%
import pandas as pd
import numpy as np

from xgboost import XGBClassifier

from src.data.load_data import load_dataset
from src.data.split_data import split_data
from src.features.mutual_information import compute_mutual_information
from src.features.shap_extractor import SHAPExtractor
# Out:
# Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)

# %%
X, y = load_dataset(
    path="../data/processed/heart_Verified.csv",
    target_col="target"
)

X.shape, y.shape
# Out:
# ((1548, 11), (1548,))

# %%
# %pip install shap xgboost scikit-learn pandas numpy matplotlib
# Out:
# Requirement already satisfied: shap in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (0.42.1)
# Requirement already satisfied: xgboost in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (1.7.6)
# Requirement already satisfied: scikit-learn in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (1.3.2)
# Requirement already satisfied: pandas in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (3.10.8)
# Requirement already satisfied: scipy in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (1.11.4)
# Requirement already satisfied: tqdm>=4.27.0 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (25.0)
# Requirement already satisfied: slicer==0.0.7 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (0.0.7)
# Requirement already satisfied: numba in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (0.63.1)
# Requirement already satisfied: cloudpickle in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from shap) (3.1.2)
# Requirement already satisfied: joblib>=1.1.1 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: six>=1.5 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: colorama in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from tqdm>=4.27.0->shap) (0.4.6)
# Requirement already satisfied: llvmlite<0.47,>=0.46.0dev0 in c:\users\dhanu\onedrive\desktop\cd_main\wfa_xgb_cvd_prediction\wfa_xgb_env\lib\site-packages (from numba->shap) (0.46.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=4,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="logloss",
    random_state=42
)

xgb_model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, gamma=None, gpu_id=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=4,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, predictor=None, random_state=42, ...)

# %%
shap_extractor = SHAPExtractor(xgb_model)

global_importance = shap_extractor.global_importance(X)
global_importance = global_importance.astype(float)

global_importance.sort_values(ascending=False).head(10)
# Out:
# slope       0.896852
# cp          0.685588
# restecg     0.341422
# oldpeak     0.331244
# thalach     0.235060
# exang       0.181895
# age         0.172537
# trestbps    0.163201
# chol        0.151310
# sex         0.125238
# Name: shap_importance, dtype: float64

# %%
mi_table = compute_mutual_information(X, y)
mi_table = mi_table.astype(float)

mi_table.sort_values(ascending=False).head(10)
# Out:
# slope       0.128619
# cp          0.052018
# exang       0.020089
# oldpeak     0.019716
# restecg     0.018155
# trestbps    0.014690
# sex         0.010855
# age         0.000000
# chol        0.000000
# fbs         0.000000
# Name: mutual_information, dtype: float64

# %%
LAMBDA_WFA = 0.6

shap_norm = (global_importance - global_importance.min()) / (
    global_importance.max() - global_importance.min() + 1e-8
)

mi_norm = (mi_table - mi_table.min()) / (
    mi_table.max() - mi_table.min() + 1e-8
)

feature_augmented_weights = (
    LAMBDA_WFA * shap_norm +
    (1 - LAMBDA_WFA) * mi_norm
)

feature_augmented_weights.name = "wfa_weight"

feature_augmented_weights.sort_values(ascending=False).head(10)
# Out:
# slope       1.000000
# cp          0.612684
# restecg     0.264488
# oldpeak     0.262157
# exang       0.157920
# thalach     0.132963
# trestbps    0.127937
# sex         0.089219
# age         0.088840
# chol        0.073860
# Name: wfa_weight, dtype: float64

# %%
os.makedirs("../experiments", exist_ok=True)

feature_augmented_weights.to_csv(
    "../experiments/feature_augmented_weights.csv"
)

print("✅ Feature-augmented WFA weights saved successfully.")
# Out:
# ✅ Feature-augmented WFA weights saved successfully.
